# %% [markdown]
# <a href="https://colab.research.google.com/github/ayeshafirdose31/mlproject-/blob/main/Simple_Linear_Reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("/content/placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x=df[["cgpa"]]
y=df[["package"]]

# %%
lr=LinearRegression()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[6.9]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2.93536272]])

# %%
lr.coef_

#slope=m
#here since the number is positive that means my angle is less than 90*
# Out:
# array([[0.57425647]])

# %%
lr.intercept_

#intercept=c
# Out:
# array([-1.02700694])

# %%
#y=mx+c

eq=0.57425647*6.9-1.02700694
eq
# Out:
# 2.935362703
